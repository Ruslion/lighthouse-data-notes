# %% [markdown]
# # XML exercise

# %% [markdown]
# Using data from [**mondial database**](https://drive.google.com/file/d/14lFT4nWHgwN36ij4XZh6OUuup-K9qLgR/view?usp=sharing) find the answers to following questions:
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
import xml.etree.ElementTree as ET
import pandas as pd

# %%
tree = ET.parse('mondial.xml')

# %%
root = tree.getroot()
root
# Out:
# <Element 'mondial' at 0x00000162DE090D18>

# %%
first_child=root[0]
print(first_child.attrib)
# Out:
# {'car_code': 'AL', 'area': '28750', 'capital': 'cty-Albania-Tirane', 'memberships': 'org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EITI org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITU org-ITUC org-IDB org-MIGA org-NATO org-OSCE org-OPCW org-OAS org-OIC org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO'}

# %%
list_countries=[]
for country in root:
    country_dict={}
    for country_property in country:
        country_dict[country_property.tag]=country_property.text
    list_countries.append(country_dict)

# %%
list_countries
# Out:
# [{'name': 'Albania',
#   'population': '2821977',
#   'population_growth': '0.3',
#   'infant_mortality': '13.19',
#   'gdp_total': '12800',
#   'gdp_agri': '19.5',
#   'gdp_ind': '12',
#   'gdp_serv': '68.5',
#   'inflation': '1.7',
#   'unemployment': '16.9',
#   'indep_date': '1912-11-28',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Greek',
#   'religion': 'Christian Orthodox',
#   'language': 'Greek',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Greece',
#   'localname': 'Ελληνική Δημοκρατία',
#   'population': '10816286',
#   'population_growth': '0.01',
#   'infant_mortality': '4.78',
#   'gdp_total': '243300',
#   'gdp_agri': '3.5',
#   'gdp_ind': '16',
#   'gdp_serv': '80.5',
#   'inflation': '-0.8',
#   'unemployment': '27.9',
#   'indep_date': '1829-01-01',
#   'government': 'parliamentary republic',
#   'encompassed': None,
#   'ethnicgroup': 'Greek',
#   'religion': 'Muslim',
#   'language': 'Greek',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'North Macedonia',
#   'localname': 'Република Cеверна Македонија',
#   'population': '2059794',
#   'population_growth': '0.21',
#   'infant_mortality': '7.9',
#   'gdp_total': '10650',
#   'gdp_agri': '10.2',
#   'gdp_ind': '27.5',
#   'gdp_serv': '62.3',
#   'inflation': '2.8',
#   'unemployment': '28.6',
#   'indep_date': '1991-09-17',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Bosniak',
#   'religion': 'Roman Catholic',
#   'language': 'Serbian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Serbia',
#   'localname': 'Република Србија',
#   'population': '7120666',
#   'population_growth': '-0.46',
#   'infant_mortality': '6.16',
#   'gdp_total': '43680',
#   'gdp_agri': '7.9',
#   'gdp_ind': '31.8',
#   'gdp_serv': '60.3',
#   'inflation': '2.2',
#   'unemployment': '20.1',
#   'indep_date': '1992-04-11',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Croat',
#   'religion': 'Protestant',
#   'language': 'Roma',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Montenegro',
#   'localname': 'Црна Гора',
#   'population': '620029',
#   'population_growth': '-0.49',
#   'gdp_total': '4518',
#   'gdp_agri': '0.8',
#   'gdp_ind': '11.3',
#   'gdp_serv': '87.9',
#   'inflation': '4',
#   'unemployment': '19.1',
#   'indep_date': '2006-06-03',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Albanian',
#   'religion': 'Roman Catholic',
#   'language': 'Albanian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Kosovo',
#   'localname': 'Republika e Kosovës',
#   'population': '1733872',
#   'gdp_total': '7150',
#   'gdp_agri': '12.9',
#   'gdp_ind': '22.6',
#   'gdp_serv': '64.5',
#   'inflation': '1.8',
#   'unemployment': '30.9',
#   'indep_date': '2008-02-17',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Serbian',
#   'religion': 'Muslim',
#   'language': 'Serbian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Andorra',
#   'localname': "Principat d'Andorra",
#   'population': '78115',
#   'population_growth': '0.17',
#   'infant_mortality': '3.69',
#   'gdp_total': '4800',
#   'gdp_agri': '14',
#   'gdp_ind': '79',
#   'gdp_serv': '6',
#   'inflation': '1.1',
#   'unemployment': '4',
#   'indep_date': '1278-09-08',
#   'government': 'parliamentary democracy that retains as its chiefs of state a co-principality',
#   'encompassed': None,
#   'ethnicgroup': 'African',
#   'religion': 'Roman Catholic',
#   'language': 'French',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'France',
#   'localname': 'la République française ',
#   'population': '64300821',
#   'population_growth': '0.45',
#   'infant_mortality': '3.31',
#   'gdp_total': '2739000',
#   'gdp_agri': '1.9',
#   'gdp_ind': '18.7',
#   'gdp_serv': '79.4',
#   'inflation': '0.9',
#   'unemployment': '10.2',
#   'government': 'republic',
#   'encompassed': None,
#   'religion': 'Buddhist',
#   'language': 'Occitan',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Spain',
#   'localname': 'el Reino de España',
#   'population': '46815916',
#   'population_growth': '0.78',
#   'infant_mortality': '2.7',
#   'gdp_total': '1356000',
#   'gdp_agri': '3.1',
#   'gdp_ind': '26',
#   'gdp_serv': '70.8',
#   'inflation': '1.8',
#   'unemployment': '26.3',
#   'indep_date': '1492-01-01',
#   'government': 'parliamentary monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Mediterranean Nordic',
#   'religion': 'Jehovas Witnesses',
#   'language': 'Basque',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Austria',
#   'localname': 'Republik Österreich (die)',
#   'population': '8499759',
#   'population_growth': '0.01',
#   'infant_mortality': '4.16',
#   'gdp_total': '417900',
#   'gdp_agri': '1.6',
#   'gdp_ind': '28.6',
#   'gdp_serv': '69.8',
#   'inflation': '2.1',
#   'unemployment': '4.9',
#   'indep_date': '1918-11-12',
#   'government': 'federal republic',
#   'encompassed': None,
#   'ethnicgroup': 'German',
#   'religion': 'Muslim',
#   'language': 'Hungarian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Czech Republic',
#   'population': '10562214',
#   'population_growth': '0.17',
#   'infant_mortality': '2.63',
#   'gdp_total': '194800',
#   'gdp_agri': '2.4',
#   'gdp_ind': '37.3',
#   'gdp_serv': '60.3',
#   'inflation': '1.4',
#   'unemployment': '7.1',
#   'indep_date': '1993-01-01',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Hungarian',
#   'religion': 'Protestant',
#   'language': 'Slovak',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Germany',
#   'localname': 'Bundesrepublik Deutschland (die)',
#   'population': '82521653',
#   'population_growth': '-0.18',
#   'infant_mortality': '3.46',
#   'gdp_total': '3593000',
#   'gdp_agri': '0.8',
#   'gdp_ind': '30.1',
#   'gdp_serv': '69',
#   'inflation': '1.6',
#   'unemployment': '5.3',
#   'indep_date': '1871-01-18',
#   'government': 'federal republic',
#   'encompassed': None,
#   'ethnicgroup': 'Turkish',
#   'religion': 'Buddhist',
#   'language': 'German',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Hungary',
#   'localname': 'Magyar Köztársaság (a)',
#   'population': '9937628',
#   'population_growth': '-0.21',
#   'infant_mortality': '5.09',
#   'gdp_total': '130600',
#   'gdp_agri': '3.4',
#   'gdp_ind': '28',
#   'gdp_serv': '68.7',
#   'inflation': '1.9',
#   'unemployment': '10.5',
#   'indep_date': '1918-11-18',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Romanian',
#   'religion': 'Protestant',
#   'language': 'Hungarian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Italy',
#   'localname': 'Repubblica Italiana (la)',
#   'population': '59433744',
#   'population_growth': '0.3',
#   'infant_mortality': '3.31',
#   'gdp_total': '2068000',
#   'gdp_agri': '2',
#   'gdp_ind': '24.4',
#   'gdp_serv': '73.5',
#   'inflation': '1.2',
#   'unemployment': '12.4',
#   'indep_date': '1861-03-17',
#   'government': 'republic',
#   'encompassed': None,
#   'religion': 'Hindu',
#   'language': 'Albanian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Liechtenstein',
#   'localname': 'Fürstentum Liechtenstein (das)',
#   'population': '36149',
#   'population_growth': '0.82',
#   'infant_mortality': '4.33',
#   'gdp_total': '5113',
#   'gdp_agri': '8',
#   'gdp_ind': '37',
#   'gdp_serv': '55',
#   'inflation': '-0.7',
#   'unemployment': '2.3',
#   'indep_date': '1806-07-12',
#   'government': 'hereditary constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Alemannic',
#   'religion': 'Protestant',
#   'language': 'German',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Slovakia',
#   'population': '5397036',
#   'population_growth': '0.03',
#   'infant_mortality': '5.35',
#   'gdp_total': '96960',
#   'gdp_agri': '3.1',
#   'gdp_ind': '30.8',
#   'gdp_serv': '67',
#   'inflation': '1.7',
#   'unemployment': '14.4',
#   'indep_date': '1993-01-01',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Polish',
#   'religion': 'Christian Orthodox',
#   'language': 'Ukrainian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Slovenia',
#   'localname': 'Republika Slovenija',
#   'population': '2058821',
#   'population_growth': '-0.23',
#   'infant_mortality': '4.04',
#   'gdp_total': '46820',
#   'gdp_agri': '2.8',
#   'gdp_ind': '28.9',
#   'gdp_serv': '68.3',
#   'inflation': '1.8',
#   'unemployment': '13.1',
#   'indep_date': '1991-06-25',
#   'government': 'parliamentary republic',
#   'encompassed': None,
#   'ethnicgroup': 'Bosniak',
#   'religion': 'Roman Catholic',
#   'language': 'Croatian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Switzerland',
#   'population': '8139631',
#   'population_growth': '0.78',
#   'infant_mortality': '3.73',
#   'gdp_total': '646200',
#   'gdp_agri': '0.7',
#   'gdp_ind': '26.8',
#   'gdp_serv': '72.5',
#   'inflation': '-0.4',
#   'unemployment': '3.2',
#   'indep_date': '1291-01-01',
#   'government': 'formally a confederation but similar in structure to a federal republic',
#   'encompassed': None,
#   'ethnicgroup': 'Romansch',
#   'religion': 'Jewish',
#   'language': 'Romansch',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Belarus',
#   'localname': 'Рэспубліка Беларусь',
#   'population': '9460692',
#   'population_growth': '-0.19',
#   'infant_mortality': '3.64',
#   'gdp_total': '69240',
#   'gdp_agri': '9.2',
#   'gdp_ind': '46.2',
#   'gdp_serv': '44.7',
#   'inflation': '19',
#   'unemployment': '1',
#   'indep_date': '1991-08-25',
#   'government': 'republic in name, although in fact a dictatorship',
#   'encompassed': None,
#   'ethnicgroup': 'Ukrainian',
#   'religion': 'Protestant',
#   'language': 'Belorussian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Latvia',
#   'localname': 'Latvijas Republika',
#   'population': '2201196',
#   'population_growth': '-0.62',
#   'infant_mortality': '7.91',
#   'gdp_total': '30380',
#   'gdp_agri': '4.9',
#   'gdp_ind': '25.7',
#   'gdp_serv': '69.4',
#   'inflation': '0.2',
#   'unemployment': '9.8',
#   'indep_date': '1991-09-06',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Lithuanian',
#   'religion': 'Christian Orthodox',
#   'language': 'Russian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Lithuania',
#   'localname': 'Lietuvos Respublika',
#   'population': '2979310',
#   'population_growth': '-0.29',
#   'infant_mortality': '6',
#   'gdp_total': '46710',
#   'gdp_agri': '3.7',
#   'gdp_ind': '28.3',
#   'gdp_serv': '68',
#   'inflation': '1.2',
#   'unemployment': '12.4',
#   'indep_date': '1991-09-06',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Belorussian',
#   'religion': 'Protestant',
#   'language': 'Polish',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Poland',
#   'localname': 'Rzeczpospolita Polska',
#   'population': '38533789',
#   'population_growth': '-0.11',
#   'infant_mortality': '6.19',
#   'gdp_total': '513900',
#   'gdp_agri': '4',
#   'gdp_ind': '33.3',
#   'gdp_serv': '62.7',
#   'inflation': '1',
#   'unemployment': '10.3',
#   'indep_date': '1918-11-11',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Byelorussian',
#   'religion': 'Roman Catholic',
#   'language': 'Polish',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Ukraine',
#   'localname': 'Украïна',
#   'population': '45633637',
#   'population_growth': '-0.64',
#   'infant_mortality': '8.1',
#   'gdp_total': '175500',
#   'gdp_agri': '9.9',
#   'gdp_ind': '29.6',
#   'gdp_serv': '60.5',
#   'inflation': '0.7',
#   'unemployment': '8',
#   'indep_date': '1991-12-01',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Jewish',
#   'religion': 'Jewish',
#   'language': 'Russian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Russia',
#   'population': '143666931',
#   'population_growth': '-0.03',
#   'infant_mortality': '7.08',
#   'gdp_total': '2113000',
#   'gdp_agri': '4.2',
#   'gdp_ind': '37.5',
#   'gdp_serv': '58.3',
#   'inflation': '6.8',
#   'unemployment': '5.8',
#   'indep_date': '1991-08-24',
#   'government': 'federation',
#   'encompassed': None,
#   'ethnicgroup': 'Chuvash',
#   'religion': 'Muslim',
#   'language': 'Russian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Belgium',
#   'localname': 'Koninkrijk België (het)',
#   'population': '11099554',
#   'population_growth': '0.05',
#   'infant_mortality': '4.18',
#   'gdp_total': '507400',
#   'gdp_agri': '0.8',
#   'gdp_ind': '22.6',
#   'gdp_serv': '76.6',
#   'inflation': '1.3',
#   'unemployment': '8.8',
#   'indep_date': '1830-10-04',
#   'government': 'federal parliamentary democracy under a constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Walloon',
#   'religion': 'Muslim',
#   'language': 'Dutch',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Luxembourg',
#   'localname': 'le Grand-Duché de Luxembourg ',
#   'population': '524853',
#   'population_growth': '1.12',
#   'infant_mortality': '4.28',
#   'gdp_total': '60540',
#   'gdp_agri': '0.3',
#   'gdp_ind': '13.3',
#   'gdp_serv': '86.4',
#   'inflation': '1.8',
#   'unemployment': '4.9',
#   'indep_date': '1890-11-24',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'German',
#   'religion': 'Jewish',
#   'language': 'English',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Netherlands',
#   'localname': 'Koninkrijk der Nederlanden (het)',
#   'population': '16843181',
#   'population_growth': '0.42',
#   'infant_mortality': '3.66',
#   'gdp_total': '722300',
#   'gdp_agri': '2.6',
#   'gdp_ind': '25.4',
#   'gdp_serv': '72.1',
#   'inflation': '2.5',
#   'unemployment': '8.3',
#   'indep_date': '1579-01-01',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Caribbean',
#   'religion': 'Buddhist',
#   'language': 'Dutch',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Bosnia and Herzegovina',
#   'localname': 'Bosna i Hercegovina',
#   'population': '3791622',
#   'population_growth': '-0.11',
#   'infant_mortality': '5.84',
#   'gdp_total': '18870',
#   'gdp_agri': '8.1',
#   'gdp_ind': '26.4',
#   'gdp_serv': '65.5',
#   'inflation': '0.2',
#   'unemployment': '44.3',
#   'indep_date': '1992-04-01',
#   'government': 'emerging federal democratic republic',
#   'encompassed': None,
#   'ethnicgroup': 'Croat',
#   'religion': 'Protestant',
#   'language': 'Serbo-Croatian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Croatia',
#   'localname': 'Republika Hrvatska',
#   'population': '4290612',
#   'population_growth': '-0.12',
#   'infant_mortality': '5.87',
#   'gdp_total': '59140',
#   'gdp_agri': '5',
#   'gdp_ind': '25.8',
#   'gdp_serv': '69.2',
#   'inflation': '2.2',
#   'unemployment': '21.6',
#   'indep_date': '1991-06-25',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Slovene',
#   'religion': 'Muslim',
#   'language': 'Serbian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Bulgaria',
#   'localname': 'Република България',
#   'population': '7284552',
#   'population_growth': '-0.83',
#   'infant_mortality': '15.08',
#   'gdp_total': '53700',
#   'gdp_agri': '6.7',
#   'gdp_ind': '30.3',
#   'gdp_serv': '63',
#   'inflation': '1.5',
#   'unemployment': '11.6',
#   'indep_date': '1908-09-22',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Armenian',
#   'religion': 'Roman Catholic',
#   'language': 'Roma',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Romania',
#   'localname': 'România',
#   'population': '20121641',
#   'population_growth': '-0.29',
#   'infant_mortality': '10.16',
#   'gdp_total': '188900',
#   'gdp_agri': '6.4',
#   'gdp_ind': '34.2',
#   'gdp_serv': '59.4',
#   'inflation': '3.2',
#   'unemployment': '7.3',
#   'indep_date': '1877-05-09',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Turkish',
#   'religion': 'Roman Catholic',
#   'language': 'Roma',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Turkey',
#   'localname': 'Türkiye Cumhuriyeti',
#   'population': '75627384',
#   'population_growth': '1.12',
#   'infant_mortality': '21.43',
#   'gdp_total': '821800',
#   'gdp_agri': '8.9',
#   'gdp_ind': '27.3',
#   'gdp_serv': '63.8',
#   'inflation': '7.6',
#   'unemployment': '9.3',
#   'indep_date': '1923-10-29',
#   'government': 'republican parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Arab',
#   'religion': 'Muslim',
#   'language': 'Kurdish',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Denmark',
#   'localname': 'Kongeriget Danmark',
#   'population': '5678348',
#   'population_growth': '0.22',
#   'infant_mortality': '4.1',
#   'gdp_total': '324300',
#   'gdp_agri': '1.5',
#   'gdp_ind': '21.7',
#   'gdp_serv': '76.8',
#   'inflation': '0.8',
#   'unemployment': '6',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'religion': 'Muslim',
#   'language': 'German',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Estonia',
#   'localname': 'Eesti Vabariik',
#   'population': '1294455',
#   'population_growth': '-0.68',
#   'infant_mortality': '6.7',
#   'gdp_total': '24280',
#   'gdp_agri': '3.9',
#   'gdp_ind': '30',
#   'gdp_serv': '66.2',
#   'inflation': '3.4',
#   'unemployment': '10.9',
#   'indep_date': '1991-09-06',
#   'government': 'parliamentary republic',
#   'encompassed': None,
#   'ethnicgroup': 'Finn',
#   'religion': 'Christian Orthodox',
#   'language': 'Russian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Faroe Islands',
#   'localname': 'Føroyar',
#   'population': '50494',
#   'population_growth': '0.49',
#   'infant_mortality': '5.71',
#   'gdp_total': '2320',
#   'gdp_agri': '16',
#   'gdp_ind': '29',
#   'gdp_serv': '55',
#   'inflation': '2.3',
#   'unemployment': '6.8',
#   'dependent': None,
#   'government': 'part of the Danish realm',
#   'encompassed': None,
#   'ethnicgroup': 'Scandinavian',
#   'religion': 'Protestant',
#   'city': '\n         '},
#  {'name': 'Finland',
#   'localname': 'Suomen tasavalta',
#   'population': '5513130',
#   'population_growth': '0.05',
#   'infant_mortality': '3.36',
#   'gdp_total': '259600',
#   'gdp_agri': '2.9',
#   'gdp_ind': '25.1',
#   'gdp_serv': '71.9',
#   'inflation': '2.2',
#   'unemployment': '8.1',
#   'indep_date': '1917-12-06',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Estonian',
#   'religion': 'Christian Orthodox',
#   'language': 'Somali',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Norway',
#   'population': '5051275',
#   'population_growth': '1.19',
#   'infant_mortality': '2.48',
#   'gdp_total': '515800',
#   'gdp_agri': '1.2',
#   'gdp_ind': '42.3',
#   'gdp_serv': '56.5',
#   'inflation': '1.9',
#   'unemployment': '3.6',
#   'indep_date': '1905-10-26',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Sami',
#   'religion': 'Muslim',
#   'language': 'Norwegian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Sweden',
#   'population': '9555893',
#   'population_growth': '0.79',
#   'infant_mortality': '2.6',
#   'gdp_total': '552000',
#   'gdp_agri': '2',
#   'gdp_ind': '31.3',
#   'gdp_serv': '66.8',
#   'inflation': '0',
#   'unemployment': '8.1',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Finn',
#   'religion': 'Roman Catholic',
#   'language': 'Finnish',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Monaco',
#   'localname': 'la Principauté de Monaco ',
#   'population': '36845',
#   'population_growth': '0.06',
#   'infant_mortality': '1.81',
#   'gdp_total': '5748',
#   'gdp_agri': '0',
#   'gdp_ind': '10',
#   'gdp_serv': '90',
#   'inflation': '1.5',
#   'unemployment': '2',
#   'indep_date': '1419-01-01',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Italian',
#   'religion': 'Roman Catholic',
#   'language': 'Dutch',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Gibraltar',
#   'population': '32577',
#   'population_growth': '0.25',
#   'infant_mortality': '6.29',
#   'gdp_total': '1106',
#   'gdp_agri': '0',
#   'gdp_ind': '0',
#   'gdp_serv': '100',
#   'inflation': '2.8',
#   'unemployment': '3',
#   'dependent': None,
#   'government': 'dependent territory of the UK',
#   'encompassed': None,
#   'religion': 'Protestant',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Guernsey',
#   'localname': 'the Bailiwick of Guernsey',
#   'population': '64540',
#   'population_growth': '0.36',
#   'infant_mortality': '3.47',
#   'gdp_total': '2742',
#   'gdp_agri': '3',
#   'gdp_ind': '10',
#   'gdp_serv': '87',
#   'inflation': '3.4',
#   'unemployment': '0.9',
#   'dependent': None,
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Norman-French',
#   'city': '\n         '},
#  {'name': 'Holy See',
#   'population': '842',
#   'indep_date': '1929-02-11',
#   'government': 'monarchical sacerdotal state',
#   'encompassed': None,
#   'religion': 'Roman Catholic',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Ceuta',
#   'population': '82376',
#   'dependent': None,
#   'government': 'dependent territory of Spain',
#   'encompassed': None,
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Melilla',
#   'population': '78476',
#   'dependent': None,
#   'government': 'dependent territory of Spain',
#   'encompassed': None,
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Iceland',
#   'localname': 'Lýðveldið Ísland',
#   'population': '329100',
#   'population_growth': '0.65',
#   'infant_mortality': '3.15',
#   'gdp_total': '14590',
#   'gdp_agri': '5.9',
#   'gdp_ind': '22.9',
#   'gdp_serv': '71.2',
#   'inflation': '3.9',
#   'unemployment': '4.5',
#   'indep_date': '1944-06-17',
#   'government': 'constitutional republic',
#   'encompassed': None,
#   'ethnicgroup': 'Celt',
#   'religion': 'Roman Catholic',
#   'language': 'Icelandic',
#   'city': '\n         '},
#  {'name': 'Ireland',
#   'localname': 'Ireland',
#   'population': '4588252',
#   'population_growth': '1.2',
#   'infant_mortality': '3.74',
#   'gdp_total': '220900',
#   'gdp_agri': '1.6',
#   'gdp_ind': '28',
#   'gdp_serv': '70.4',
#   'inflation': '0.6',
#   'unemployment': '13.5',
#   'indep_date': '1921-12-06',
#   'government': 'republic, parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'African',
#   'religion': 'Anglican',
#   'language': 'English',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'San Marino',
#   'localname': 'Repubblica di San Marino (la)',
#   'population': '32440',
#   'population_growth': '0.87',
#   'infant_mortality': '4.52',
#   'gdp_total': '1866',
#   'gdp_agri': '0.1',
#   'gdp_ind': '39.2',
#   'gdp_serv': '60.7',
#   'inflation': '2.8',
#   'unemployment': '7',
#   'indep_date': '0301-01-01',
#   'government': 'republic',
#   'encompassed': None,
#   'religion': 'Roman Catholic',
#   'language': 'Italian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Jersey',
#   'localname': 'the Bailiwick of Jersey',
#   'population': '97857',
#   'population_growth': '0.81',
#   'infant_mortality': '3.86',
#   'gdp_total': '5100',
#   'gdp_agri': '2',
#   'gdp_ind': '2',
#   'gdp_serv': '96',
#   'inflation': '3.7',
#   'unemployment': '1.7',
#   'dependent': None,
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Norman-French',
#   'language': 'Portuguese',
#   'city': '\n         '},
#  {'name': 'Malta',
#   'localname': 'the Republic of Malta ',
#   'population': '417432',
#   'population_growth': '0.33',
#   'infant_mortality': '3.59',
#   'gdp_total': '9541',
#   'gdp_agri': '1.4',
#   'gdp_ind': '25.3',
#   'gdp_serv': '73.3',
#   'inflation': '1',
#   'unemployment': '6.4',
#   'indep_date': '1964-09-21',
#   'government': 'republic',
#   'encompassed': None,
#   'religion': 'Roman Catholic',
#   'language': 'English',
#   'city': '\n         '},
#  {'name': 'Isle of Man',
#   'localname': 'the Isle of Man',
#   'population': '84497',
#   'population_growth': '0.8',
#   'infant_mortality': '4.17',
#   'gdp_total': '4076',
#   'gdp_agri': '1',
#   'gdp_ind': '11',
#   'gdp_serv': '88',
#   'inflation': '5',
#   'unemployment': '2',
#   'dependent': None,
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'language': 'English',
#   'city': '\n         '},
#  {'name': 'Moldova',
#   'localname': 'Republica Moldova',
#   'population': '3559541',
#   'population_growth': '-1.02',
#   'infant_mortality': '12.93',
#   'gdp_total': '7932',
#   'gdp_agri': '13.8',
#   'gdp_ind': '19.9',
#   'gdp_serv': '66.2',
#   'inflation': '4.6',
#   'unemployment': '5.8',
#   'indep_date': '1991-08-27',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Bulgarian',
#   'religion': 'Jewish',
#   'language': 'Ukrainian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Portugal',
#   'localname': 'República Portuguesa (a)',
#   'population': '10561614',
#   'population_growth': '0.12',
#   'infant_mortality': '4.48',
#   'gdp_total': '219300',
#   'gdp_agri': '2.6',
#   'gdp_ind': '22.2',
#   'gdp_serv': '75.2',
#   'inflation': '0.4',
#   'unemployment': '16.8',
#   'indep_date': '1139-07-25',
#   'government': 'republic; parliamentary democracy',
#   'encompassed': None,
#   'religion': 'Protestant',
#   'language': 'Portuguese',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Svalbard',
#   'localname': 'Svalbard',
#   'population': '1872',
#   'population_growth': '-0.03',
#   'dependent': None,
#   'government': 'territory of Norway administered by the Ministry of Industry',
#   'encompassed': None,
#   'ethnicgroup': 'Russian Ukrainian',
#   'city': '\n         '},
#  {'name': 'United Kingdom',
#   'localname': 'the United Kingdom of Great Britain and Northern Ireland',
#   'population': '64105654',
#   'population_growth': '0.54',
#   'infant_mortality': '4.44',
#   'gdp_total': '2490000',
#   'gdp_agri': '0.7',
#   'gdp_ind': '20.5',
#   'gdp_serv': '78.9',
#   'inflation': '2',
#   'unemployment': '7.2',
#   'indep_date': '1801-01-01',
#   'government': 'constitutional monarchy and Commonwealth realm',
#   'encompassed': None,
#   'ethnicgroup': 'Pakistani',
#   'religion': 'Buddhist',
#   'language': 'English',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Afghanistan',
#   'localname': 'جُمْهُورِئ إِسْلامِئ أَفْغَانِسْتَان',
#   'population': '26023100',
#   'population_growth': '2.29',
#   'infant_mortality': '117.23',
#   'gdp_total': '20650',
#   'gdp_agri': '20',
#   'gdp_ind': '25.6',
#   'gdp_serv': '54.4',
#   'inflation': '6.8',
#   'unemployment': '35',
#   'indep_date': '1919-08-19',
#   'government': 'Islamic republic',
#   'encompassed': None,
#   'ethnicgroup': 'Hazara',
#   'religion': 'Muslim',
#   'language': 'Afghan Persian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'China',
#   'population': '1360720000',
#   'population_growth': '0.44',
#   'infant_mortality': '14.79',
#   'gdp_total': '9330000',
#   'gdp_agri': '10',
#   'gdp_ind': '43.9',
#   'gdp_serv': '46.1',
#   'inflation': '2.6',
#   'unemployment': '4.1',
#   'government': 'Communist state',
#   'encompassed': None,
#   'ethnicgroup': 'Han Chinese',
#   'religion': 'Christian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Iran',
#   'localname': 'جُمْهُورِئ إِسْلامِئ إِيرَان',
#   'population': '79926270',
#   'population_growth': '1.22',
#   'infant_mortality': '39',
#   'gdp_total': '411900',
#   'gdp_agri': '10.6',
#   'gdp_ind': '44.9',
#   'gdp_serv': '44.5',
#   'inflation': '42.3',
#   'unemployment': '16',
#   'government': 'theocratic republic',
#   'encompassed': None,
#   'ethnicgroup': 'Gilaki Mazandarani',
#   'religion': 'Bahai',
#   'language': 'Turkic',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Pakistan',
#   'localname': 'the Islamic Republic of Pakistan',
#   'population': '207776954',
#   'population_growth': '1.49',
#   'infant_mortality': '57.48',
#   'gdp_total': '236500',
#   'gdp_agri': '25.3',
#   'gdp_ind': '21.6',
#   'gdp_serv': '53.1',
#   'inflation': '7.7',
#   'unemployment': '6.6',
#   'indep_date': '1947-08-14',
#   'government': 'federal republic',
#   'encompassed': None,
#   'religion': 'Muslim',
#   'language': 'Siraiki',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Tajikistan',
#   'localname': 'Љумњурии Тољикистон',
#   'population': '8161100',
#   'population_growth': '1.75',
#   'infant_mortality': '35.03',
#   'gdp_total': '8513',
#   'gdp_agri': '21.1',
#   'gdp_ind': '23.2',
#   'gdp_serv': '55.7',
#   'inflation': '3.7',
#   'unemployment': '2.5',
#   'indep_date': '1991-09-09',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Kyrgyz',
#   'religion': 'Muslim',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Turkmenistan',
#   'localname': 'Türkmenistan',
#   'population': '6550000',
#   'population_growth': '1.14',
#   'infant_mortality': '38.13',
#   'gdp_total': '40560',
#   'gdp_agri': '7.2',
#   'gdp_ind': '24.4',
#   'gdp_serv': '68.4',
#   'inflation': '9',
#   'unemployment': '60',
#   'indep_date': '1991-10-27',
#   'government': 'authoritarian presidential rule',
#   'encompassed': None,
#   'ethnicgroup': 'Russian',
#   'religion': 'Christian Orthodox',
#   'language': 'Uzbek',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Uzbekistan',
#   'population': '32120500',
#   'population_growth': '0.93',
#   'infant_mortality': '19.84',
#   'gdp_total': '55180',
#   'gdp_agri': '19.1',
#   'gdp_ind': '32.2',
#   'gdp_serv': '48.7',
#   'inflation': '10.1',
#   'unemployment': '4.9',
#   'indep_date': '1991-08-31',
#   'government': 'republic; authoritarian presidential rule with little power outside the executive branch',
#   'encompassed': None,
#   'ethnicgroup': 'Tatar',
#   'religion': 'Christian Orthodox',
#   'language': 'Tajik',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Armenia',
#   'localname': 'Հայաստանի Հանրապետություն',
#   'population': '3026879',
#   'population_growth': '-0.13',
#   'infant_mortality': '13.97',
#   'gdp_total': '10440',
#   'gdp_agri': '20.6',
#   'gdp_ind': '37.3',
#   'gdp_serv': '42.1',
#   'inflation': '6.2',
#   'unemployment': '17.3',
#   'indep_date': '1918-05-28',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Yezidi',
#   'religion': 'Yezidi',
#   'language': 'Russian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Georgia',
#   'localname': 'საქართველო ',
#   'population': '4483800',
#   'population_growth': '-0.11',
#   'infant_mortality': '16.68',
#   'gdp_total': '15950',
#   'gdp_agri': '8.5',
#   'gdp_ind': '21.6',
#   'gdp_serv': '69.9',
#   'inflation': '-0.5',
#   'unemployment': '15',
#   'indep_date': '1991-04-09',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Russian',
#   'religion': 'Roman Catholic',
#   'language': 'Azeri',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Azerbaijan',
#   'localname': 'Azǝrbaycan Respublikası',
#   'population': '9356500',
#   'population_growth': '0.99',
#   'infant_mortality': '26.67',
#   'gdp_total': '76010',
#   'gdp_agri': '6.2',
#   'gdp_ind': '63',
#   'gdp_serv': '30.8',
#   'inflation': '2.4',
#   'unemployment': '6',
#   'indep_date': '1991-08-30',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Armenian',
#   'religion': 'Christian Orthodox',
#   'language': 'Armenian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Bahrain',
#   'population': '1234596',
#   'population_growth': '2.49',
#   'infant_mortality': '9.68',
#   'gdp_total': '28360',
#   'gdp_agri': '0.3',
#   'gdp_ind': '46.7',
#   'gdp_serv': '53',
#   'inflation': '3.1',
#   'unemployment': '15',
#   'indep_date': '1971-08-15',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Iranian',
#   'religion': 'Muslim',
#   'city': '\n         '},
#  {'name': 'Bangladesh',
#   'localname': 'গণপ্রজাতন্ত্রী বাংলাদেশ',
#   'population': '149772364',
#   'population_growth': '1.6',
#   'infant_mortality': '45.67',
#   'gdp_total': '140200',
#   'gdp_agri': '17.2',
#   'gdp_ind': '28.9',
#   'gdp_serv': '53.9',
#   'inflation': '7.6',
#   'unemployment': '5',
#   'indep_date': '1971-12-16',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Bengali',
#   'religion': 'Hindu',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Myanmar',
#   'localname': 'ပြည်ထောင်စု သမ္မတ မြန်မာနိုင်ငံတော်',
#   'population': '51419420',
#   'population_growth': '1.03',
#   'infant_mortality': '44.91',
#   'gdp_total': '59430',
#   'gdp_agri': '38',
#   'gdp_ind': '20.3',
#   'gdp_serv': '41.7',
#   'inflation': '5.7',
#   'unemployment': '5.2',
#   'indep_date': '1948-01-04',
#   'government': 'parliamentary government took power in March 2011',
#   'encompassed': None,
#   'ethnicgroup': 'Mon',
#   'religion': 'Buddhist',
#   'language': 'Burmese',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'India',
#   'localname': 'the Republic of India',
#   'population': '1210854977',
#   'population_growth': '1.25',
#   'infant_mortality': '43.19',
#   'gdp_total': '1670000',
#   'gdp_agri': '17.4',
#   'gdp_ind': '25.8',
#   'gdp_serv': '56.9',
#   'inflation': '9.6',
#   'unemployment': '8.8',
#   'indep_date': '1947-08-15',
#   'government': 'federal republic',
#   'encompassed': None,
#   'ethnicgroup': 'Mongol',
#   'religion': 'Jains',
#   'language': 'Hindi',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Bhutan',
#   'localname': 'འབྲུག་གྷལ་ཁབ',
#   'population': '733004',
#   'population_growth': '1.13',
#   'infant_mortality': '37.89',
#   'gdp_total': '2133',
#   'gdp_agri': '13.8',
#   'gdp_ind': '41.2',
#   'gdp_serv': '45',
#   'inflation': '11',
#   'unemployment': '2.1',
#   'indep_date': '1949-08-08',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Nepalese',
#   'religion': 'Muslim',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Brunei',
#   'localname': 'Brunei Darussalam',
#   'population': '393372',
#   'population_growth': '1.65',
#   'infant_mortality': '10.48',
#   'gdp_total': '16560',
#   'gdp_agri': '0.7',
#   'gdp_ind': '70.9',
#   'gdp_serv': '28.4',
#   'inflation': '1',
#   'unemployment': '2.6',
#   'indep_date': '1984-01-01',
#   'government': 'constitutional sultanate (locally known as Malay Islamic Monarchy)',
#   'encompassed': None,
#   'ethnicgroup': 'Malay',
#   'religion': 'Buddhist',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Malaysia',
#   'localname': 'Malaysia',
#   'population': '27565821',
#   'population_growth': '1.47',
#   'infant_mortality': '13.69',
#   'gdp_total': '312400',
#   'gdp_agri': '11.2',
#   'gdp_ind': '40.6',
#   'gdp_serv': '48.1',
#   'inflation': '2.2',
#   'unemployment': '3.1',
#   'indep_date': '1957-08-31',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Borneo indigenous',
#   'religion': 'Hindu',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Laos',
#   'localname': 'ສາທາລະນະລັດປະຊາທິປະໄຕປະຊາຊົນລາວ',
#   'population': '6514432',
#   'population_growth': '1.59',
#   'infant_mortality': '54.53',
#   'gdp_total': '10100',
#   'gdp_agri': '30.5',
#   'gdp_ind': '32',
#   'gdp_serv': '37.5',
#   'inflation': '6.5',
#   'unemployment': '1.9',
#   'indep_date': '1949-07-19',
#   'government': 'Communist state',
#   'encompassed': None,
#   'ethnicgroup': 'Vietnamese/Chinese',
#   'religion': 'Buddhist',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Thailand',
#   'localname': 'ราชอาณาจักรไทย',
#   'population': '65981659',
#   'population_growth': '0.35',
#   'infant_mortality': '9.86',
#   'gdp_total': '400900',
#   'gdp_agri': '12.1',
#   'gdp_ind': '43.6',
#   'gdp_serv': '44.2',
#   'inflation': '2.2',
#   'unemployment': '0.7',
#   'indep_date': '1238-01-01',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Thai',
#   'religion': 'Hindu',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Cambodia',
#   'localname': 'ព្រះរាជាណាចក្រ កម្ពុជា',
#   'population': '14364931',
#   'population_growth': '1.63',
#   'infant_mortality': '51.36',
#   'gdp_total': '15640',
#   'gdp_agri': '34.8',
#   'gdp_ind': '24.5',
#   'gdp_serv': '40.7',
#   'inflation': '3.2',
#   'unemployment': '0',
#   'indep_date': '1949-11-09',
#   'government': 'multiparty democracy under a constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Vietnamese',
#   'religion': 'Buddhist',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Vietnam',
#   'population': '88772900',
#   'population_growth': '1',
#   'infant_mortality': '18.99',
#   'gdp_total': '170000',
#   'gdp_agri': '19.3',
#   'gdp_ind': '38.5',
#   'gdp_serv': '42.2',
#   'inflation': '6.8',
#   'unemployment': '1.3',
#   'indep_date': '1945-09-02',
#   'government': 'Communist state',
#   'encompassed': None,
#   'ethnicgroup': 'Nung',
#   'religion': 'Muslim',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Kazakhstan',
#   'localname': 'Қазақстан Республикасы',
#   'population': '17165239',
#   'population_growth': '1.17',
#   'infant_mortality': '21.61',
#   'gdp_total': '224900',
#   'gdp_agri': '5.2',
#   'gdp_ind': '37.9',
#   'gdp_serv': '56.9',
#   'inflation': '5.8',
#   'unemployment': '5.3',
#   'indep_date': '1991-12-16',
#   'government': 'republic; authoritarian presidential rule, with little power outside the executive branch',
#   'encompassed': None,
#   'ethnicgroup': 'German',
#   'religion': 'Christian Orthodox',
#   'language': 'Kazakh',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'North Korea',
#   'localname': '조선 민주주의 인민 공화국',
#   'population': '24500520',
#   'population_growth': '0.53',
#   'infant_mortality': '24.5',
#   'gdp_total': '28000',
#   'gdp_agri': '23.4',
#   'gdp_ind': '47.2',
#   'gdp_serv': '29.4',
#   'indep_date': '1945-08-15',
#   'government': 'Communist state one-man dictatorship',
#   'encompassed': None,
#   'language': 'Korean',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Kyrgyzstan',
#   'localname': 'Кыргыз Республикасы',
#   'population': '6256700',
#   'population_growth': '1.04',
#   'infant_mortality': '28.71',
#   'gdp_total': '7234',
#   'gdp_agri': '20.8',
#   'gdp_ind': '34.4',
#   'gdp_serv': '44.8',
#   'inflation': '6.8',
#   'unemployment': '8.6',
#   'indep_date': '1991-08-31',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Uighur',
#   'religion': 'Christian Orthodox',
#   'language': 'Dungun',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Hong Kong',
#   'population': '7071576',
#   'population_growth': '0.41',
#   'infant_mortality': '2.73',
#   'gdp_total': '272100',
#   'gdp_agri': '0',
#   'gdp_ind': '6.9',
#   'gdp_serv': '93',
#   'inflation': '4.4',
#   'unemployment': '3.1',
#   'dependent': None,
#   'government': 'limited democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Indonesian',
#   'religion': 'Christian',
#   'language': 'English',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Macao',
#   'population': '552503',
#   'population_growth': '0.83',
#   'infant_mortality': '3.13',
#   'gdp_total': '51680',
#   'gdp_agri': '0',
#   'gdp_ind': '6.5',
#   'gdp_serv': '93.5',
#   'inflation': '5.5',
#   'unemployment': '1.8',
#   'dependent': None,
#   'government': 'limited democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Portuguese',
#   'religion': 'Buddhist',
#   'language': 'Portuguese',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Mongolia',
#   'localname': 'Монгол улс',
#   'population': '2754685',
#   'population_growth': '1.37',
#   'infant_mortality': '23.15',
#   'gdp_total': '11140',
#   'gdp_agri': '16.5',
#   'gdp_ind': '32.6',
#   'gdp_serv': '50.9',
#   'inflation': '8.2',
#   'unemployment': '9',
#   'indep_date': '1921-03-13',
#   'government': 'parliamentary',
#   'encompassed': None,
#   'ethnicgroup': 'Kazak',
#   'religion': 'Muslim',
#   'language': 'Khalkha Mongol',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Nepal',
#   'localname': 'संघीय लोकतान्त्रिक गणतन्त्र नेपाल',
#   'population': '26494504',
#   'population_growth': '1.82',
#   'infant_mortality': '40.43',
#   'gdp_total': '19340',
#   'gdp_agri': '36.8',
#   'gdp_ind': '14.5',
#   'gdp_serv': '48.7',
#   'inflation': '6.7',
#   'unemployment': '46',
#   'indep_date': '1768-01-01',
#   'government': 'federal democratic republic',
#   'encompassed': None,
#   'religion': 'Christian',
#   'language': 'Nepali',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Christmas Island',
#   'population': '2072',
#   'dependent': None,
#   'government': 'territory of Australia',
#   'encompassed': None,
#   'ethnicgroup': 'European',
#   'religion': 'Buddhist',
#   'city': '\n         '},
#  {'name': 'Cocos Islands',
#   'population': '596',
#   'dependent': None,
#   'government': 'territory of Australia',
#   'encompassed': None,
#   'religion': 'Christian',
#   'city': '\n         '},
#  {'name': 'Cyprus',
#   'localname': 'Κυπριακή Δημοκρατία',
#   'population': '840407',
#   'population_growth': '1.48',
#   'infant_mortality': '8.54',
#   'gdp_total': '21780',
#   'gdp_agri': '2.4',
#   'gdp_ind': '15.9',
#   'gdp_serv': '81.7',
#   'inflation': '0.2',
#   'unemployment': '17.4',
#   'indep_date': '1960-08-16',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Turkish',
#   'religion': 'Muslim',
#   'language': 'Turkish',
#   'city': '\n         '},
#  {'name': 'Gaza Strip',
#   'population': '1899291',
#   'population_growth': '4.55',
#   'infant_mortality': '30.6',
#   'gdp_total': '1700',
#   'inflation': '5.7',
#   'encompassed': None,
#   'ethnicgroup': 'Arab',
#   'religion': 'Christian',
#   'language': 'Hebrew',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Israel',
#   'localname': 'دولة إسرائيل',
#   'population': '7420368',
#   'population_growth': '1.46',
#   'infant_mortality': '3.98',
#   'gdp_total': '272700',
#   'gdp_agri': '2.4',
#   'gdp_ind': '31.2',
#   'gdp_serv': '66.4',
#   'inflation': '1.7',
#   'unemployment': '5.8',
#   'indep_date': '1948-05-14',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Arab',
#   'religion': 'Druze',
#   'language': 'Arabic',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Egypt',
#   'localname': 'جمهورية مصر العربية',
#   'population': '94798827',
#   'population_growth': '1.84',
#   'infant_mortality': '22.41',
#   'gdp_total': '262000',
#   'gdp_agri': '14.5',
#   'gdp_ind': '37.5',
#   'gdp_serv': '48',
#   'inflation': '9',
#   'unemployment': '13.4',
#   'indep_date': '1922-02-28',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Egypt Arab',
#   'religion': 'Coptic Christian',
#   'language': 'Arabic',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Indonesia',
#   'localname': 'Republik Indonesia',
#   'population': '252124458',
#   'population_growth': '0.95',
#   'infant_mortality': '25.16',
#   'gdp_total': '867500',
#   'gdp_agri': '14.3',
#   'gdp_ind': '46.6',
#   'gdp_serv': '39.1',
#   'inflation': '7.7',
#   'unemployment': '6.6',
#   'indep_date': '1945-08-17',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Malay',
#   'religion': 'Hindu',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Timor-Leste',
#   'localname': 'República Democrática de Timor-Leste',
#   'population': '1066582',
#   'population_growth': '2.44',
#   'infant_mortality': '38.79',
#   'gdp_total': '6129',
#   'gdp_agri': '2.6',
#   'gdp_ind': '81.6',
#   'gdp_serv': '15.8',
#   'inflation': '4.5',
#   'unemployment': '18.4',
#   'indep_date': '2002-05-20',
#   'government': 'republic',
#   'encompassed': None,
#   'religion': 'Roman Catholic',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Papua New Guinea',
#   'localname': 'Papua New Guinea',
#   'population': '7275324',
#   'population_growth': '1.84',
#   'infant_mortality': '39.67',
#   'gdp_total': '16100',
#   'gdp_agri': '27.6',
#   'gdp_ind': '39.1',
#   'gdp_serv': '33.3',
#   'inflation': '3.8',
#   'unemployment': '1.9',
#   'indep_date': '1975-09-16',
#   'government': 'constitutional parliamentary democracy and a Commonwealth realm',
#   'encompassed': None,
#   'religion': 'Presbyterian',
#   'language': 'English',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Iraq',
#   'localname': 'جمهورية العراق',
#   'population': '33330512',
#   'population_growth': '2.23',
#   'infant_mortality': '37.53',
#   'gdp_total': '221800',
#   'gdp_agri': '3.3',
#   'gdp_ind': '64.6',
#   'gdp_serv': '32.1',
#   'inflation': '2',
#   'unemployment': '16',
#   'indep_date': '1932-10-03',
#   'government': 'parliamentary democracy',
#   'encompassed': None,
#   'ethnicgroup': 'Assyrian',
#   'religion': 'Christian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Jordan',
#   'localname': 'المملكة الأردنية الهاشمية',
#   'population': '6249000',
#   'population_growth': '3.86',
#   'infant_mortality': '15.73',
#   'gdp_total': '34080',
#   'gdp_agri': '3.2',
#   'gdp_ind': '29.9',
#   'gdp_serv': '67',
#   'inflation': '5.9',
#   'unemployment': '14',
#   'indep_date': '1946-05-25',
#   'government': 'constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Circassian',
#   'religion': 'Christian',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Kuwait',
#   'localname': 'دولة الكويت',
#   'population': '2991580',
#   'population_growth': '1.7',
#   'infant_mortality': '7.51',
#   'gdp_total': '179500',
#   'gdp_agri': '0.3',
#   'gdp_ind': '50.6',
#   'gdp_serv': '49.1',
#   'inflation': '2.8',
#   'unemployment': '3.4',
#   'indep_date': '1961-06-19',
#   'government': 'constitutional emirate',
#   'encompassed': None,
#   'ethnicgroup': 'Kuwaiti',
#   'religion': 'Muslim',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Saudi Arabia',
#   'localname': 'المملكة العربية السعودية',
#   'population': '27136977',
#   'population_growth': '1.49',
#   'infant_mortality': '14.58',
#   'gdp_total': '718500',
#   'gdp_agri': '2',
#   'gdp_ind': '62.5',
#   'gdp_serv': '35.5',
#   'inflation': '3.7',
#   'unemployment': '10.5',
#   'indep_date': '1932-09-23',
#   'government': 'monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Afro-Asian',
#   'religion': 'Muslim',
#   'language': 'Arabic',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Syria',
#   'localname': 'الجمهورية العربية السورية',
#   'population': '20866000',
#   'population_growth': '-9.73',
#   'infant_mortality': '15.79',
#   'gdp_total': '64700',
#   'gdp_agri': '17.6',
#   'gdp_ind': '22.2',
#   'gdp_serv': '60.2',
#   'inflation': '59.1',
#   'unemployment': '17.8',
#   'indep_date': '1946-04-17',
#   'government': 'republic under an authoritarian regime',
#   'encompassed': None,
#   'ethnicgroup': 'Arab',
#   'religion': 'Christian',
#   'border': None,
#   'province': '\n         '},
#  {'name': 'Lebanon',
#   'localname': 'الجمهورية اللبنانية',
#   'population': '4341092',
#   'population_growth': '9.37',
#   'infant_mortality': '7.98',
#   'gdp_total': '43490',
#   'gdp_agri': '4.6',
#   'gdp_ind': '20',
#   'gdp_serv': '75.4',
#   'inflation': '5',
#   'indep_date': '1943-11-22',
#   'government': 'republic',
#   'encompassed': None,
#   'ethnicgroup': 'Arab',
#   'religion': 'Muslim',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'West Bank',
#   'population': '2881687',
#   'population_growth': '4.99',
#   'infant_mortality': '28.6',
#   'gdp_total': '3700',
#   'gdp_agri': '33',
#   'gdp_ind': '7',
#   'gdp_serv': '60',
#   'inflation': '14',
#   'encompassed': None,
#   'ethnicgroup': 'Arab',
#   'religion': 'Christian',
#   'language': 'Hebrew',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Japan',
#   'population': '127298000',
#   'population_growth': '-0.13',
#   'infant_mortality': '2.13',
#   'gdp_total': '5007000',
#   'gdp_agri': '1.1',
#   'gdp_ind': '25.6',
#   'gdp_serv': '73.2',
#   'inflation': '0.2',
#   'unemployment': '4.1',
#   'government': 'a parliamentary government with a constitutional monarchy',
#   'encompassed': None,
#   'ethnicgroup': 'Japanese',
#   'religion': 'Buddhist',
#   'language': 'Japanese',
#   'province': '\n         '},
#  {'name': 'South Korea',
#   'localname': '대한 민국',
#   'population': '51269554',
#   'population_growth': '0.16',
#   'infant_mortality': '3.93',
#   'gdp_total': '1198000',
#   'gdp_agri': '2.6',
#   'gdp_ind': '39.2',
#   'gdp_serv': '58.2',
#   'inflation': '1.1',
#   'unemployment': '3.2',
#   'indep_date': '1945-08-15',
#   'government': 'republic',
#   'encompassed': None,
#   'religion': 'Chondogyo',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'Maldives',
#   'localname': 'ދިވެހިރާއްޖޭގެ ޖުމުހޫރިއްޔާ',
#   'population': '341256',
#   'population_growth': '-0.09',
#   'infant_mortality': '24.59',
#   'gdp_total': '2270',
#   'gdp_agri': '3',
#   'gdp_ind': '17',
#   'gdp_serv': '80',
#   'inflation': '5.1',
#   'unemployment': '28',
#   'indep_date': '1965-07-26',
#   'government': 'republic',
#   'encompassed': None,
#   'religion': 'Muslim',
#   'city': '\n         '},
#  {'name': 'Oman',
#   'localname': 'سلطنة عمان',
#   'population': '3623001',
#   'population_growth': '2.06',
#   'infant_mortality': '14',
#   'gdp_total': '81950',
#   'gdp_agri': '1',
#   'gdp_ind': '64.4',
#   'gdp_serv': '34.6',
#   'inflation': '1.6',
#   'unemployment': '15',
#   'indep_date': '1650-01-01',
#   'government': 'monarchy',
#   'encompassed': None,
#   'religion': 'Muslim',
#   'border': None,
#   'city': '\n         '},
#  {'name': 'United Arab Emirates',
#   'localname': 'الإمارات العربية المتحدة',
#   'population': '9121167',
#   'population_growth': '2.71',
#   'infant_mortality': '10.92',
#   'gdp_total': '390000',
#   'gdp_agri': '0.6',
#   'gdp_ind': '61.1',
#   'gdp_serv': '38.2',
#   'inflation': '1.3',
#   'unemployment': '2.4',
#   'indep_date': '1971-12-02',
#   'government': 'federation with specified powers delegated to the UAE federal government and other powers reserved to member emirates',
#   'encompassed': None,
#   'ethnicgroup': 'Arab Iranian',
#   'religion': 'Muslim',
#   'border': None,
#   'city': '\n         '},
# ...
#   'estuary': '\n         '},
#  {'name': 'Oranje',
#   'located': None,
#   'to': None,
#   'area': '973000',
#   'length': '2160',
#   'source': '\n         ',
#   'estuary': '\n         '},
#  {'name': 'Vaal',
#   'located': None,
#   'to': None,
#   'area': '973000',
#   'length': '1251',
#   'source': '\n         ',
#   'estuary': '\n         '},
#  {'name': 'Mangoky',
#   'to': None,
#   'area': '55750',
#   'length': '714',
#   'source': '\n         ',
#   'estuary': '\n         '},
#  {'name': 'Murray River',
#   'located': None,
#   'through': None,
#   'to': None,
#   'area': '1058549',
#   'length': '2375',
#   'source': '\n         ',
#   'estuary': '\n         '},
#  {'name': 'Darling River',
#   'located': None,
#   'to': None,
#   'length': '2739',
#   'source': '\n         ',
#   'estuary': '\n         '},
#  {'name': 'Murrumbidgee River',
#   'located': None,
#   'through': None,
#   'to': None,
#   'area': '81640',
#   'length': '1579',
#   'source': '\n         ',
#   'estuary': '\n         '},
#  {'name': 'Eucumbene River',
#   'located': None,
#   'through': None,
#   'to': None,
#   'length': '83',
#   'source': '\n         ',
#   'estuary': '\n         '},
#  {'name': 'Snowy River',
#   'located': None,
#   'through': None,
#   'to': None,
#   'length': '403',
#   'source': '\n         ',
#   'estuary': '\n         '},
#  {'name': 'Waikato River',
#   'through': None,
#   'to': None,
#   'area': '14260',
#   'length': '425',
#   'source': '\n         ',
#   'estuary': '\n         '},
#  {'name': 'Clutha River',
#   'to': None,
#   'area': '21960',
#   'length': '338',
#   'source': '\n         ',
#   'estuary': '\n         '},
#  {'name': 'Inarijärvi',
#   'located': None,
#   'to': None,
#   'area': '1040',
#   'latitude': '68.95',
#   'longitude': '27.7',
#   'elevation': '119',
#   'depth': '92'},
#  {'name': 'Oulujärvi',
#   'located': None,
#   'to': None,
#   'area': '928',
#   'latitude': '64.3',
#   'longitude': '27.25',
#   'elevation': '123',
#   'depth': '35'},
#  {'name': 'Saimaa',
#   'located': None,
#   'to': None,
#   'area': '4370',
#   'latitude': '61.3',
#   'longitude': '28.0',
#   'elevation': '76',
#   'depth': '85'},
#  {'name': 'Päijänne',
#   'located': None,
#   'to': None,
#   'area': '1118',
#   'latitude': '61.5',
#   'longitude': '25.4',
#   'elevation': '78',
#   'depth': '95'},
#  {'name': 'Mjoesa-See',
#   'located': None,
#   'to': None,
#   'area': '368',
#   'latitude': '60.65',
#   'longitude': '11',
#   'elevation': '123',
#   'depth': '449'},
#  {'name': 'Storuman',
#   'located': None,
#   'to': None,
#   'area': '173',
#   'latitude': '65.22',
#   'longitude': '16.88',
#   'elevation': '419',
#   'depth': '139'},
#  {'name': 'Siljan',
#   'located': None,
#   'to': None,
#   'area': '290',
#   'latitude': '60.85',
#   'longitude': '14.8',
#   'elevation': '161',
#   'depth': '134'},
#  {'name': 'Mälaren',
#   'located': None,
#   'to': None,
#   'area': '1140',
#   'latitude': '59.4',
#   'longitude': '17.1',
#   'elevation': '0.7',
#   'depth': '66'},
#  {'name': 'Vänern',
#   'located': None,
#   'to': None,
#   'area': '5648',
#   'latitude': '58.8',
#   'longitude': '13.3',
#   'elevation': '44',
#   'depth': '106'},
#  {'name': 'Vättern',
#   'located': None,
#   'to': None,
#   'area': '1900',
#   'latitude': '58.3',
#   'longitude': '14.5',
#   'elevation': '88',
#   'depth': '119'},
#  {'name': 'Arresø',
#   'located': None,
#   'to': None,
#   'area': '40.2',
#   'latitude': '56',
#   'longitude': '12.1',
#   'depth': '5.6'},
#  {'name': 'Lough Neagh',
#   'located': None,
#   'to': None,
#   'area': '392',
#   'latitude': '54.6',
#   'longitude': '-6.4',
#   'elevation': '15',
#   'depth': '25'},
#  {'name': 'Loch Ness',
#   'located': None,
#   'to': None,
#   'area': '56',
#   'latitude': '57.31',
#   'longitude': '-4.44',
#   'elevation': '16',
#   'depth': '226'},
#  {'name': 'Loch Lomond',
#   'located': None,
#   'to': None,
#   'area': '71',
#   'latitude': '56.08',
#   'longitude': '-4.59',
#   'elevation': '7.9',
#   'depth': '190'},
#  {'name': 'Bodensee',
#   'located': None,
#   'to': None,
#   'area': '538.5',
#   'latitude': '47.6',
#   'longitude': '9.4',
#   'elevation': '395',
#   'depth': '254'},
#  {'name': 'Chiemsee',
#   'located': None,
#   'to': None,
#   'area': '80',
#   'latitude': '47.9',
#   'longitude': '12.4',
#   'elevation': '518',
#   'depth': '73'},
#  {'name': 'Starnberger See',
#   'located': None,
#   'to': None,
#   'area': '56.36',
#   'latitude': '47.92',
#   'longitude': '11.32',
#   'elevation': '584',
#   'depth': '127.7'},
#  {'name': 'Ammersee',
#   'located': None,
#   'to': None,
#   'area': '46.6',
#   'latitude': '48',
#   'longitude': '11.6',
#   'elevation': '533',
#   'depth': '81.1'},
#  {'name': 'Laacher Maar',
#   'located': None,
#   'area': '3.3',
#   'latitude': '50.4',
#   'longitude': '7.3',
#   'elevation': '275',
#   'depth': '53'},
#  {'name': 'Lac Leman',
#   'located': None,
#   'to': None,
#   'area': '581',
#   'latitude': '46.5',
#   'longitude': '6.5',
#   'elevation': '372',
#   'depth': '310'},
#  {'name': 'Zürichsee',
#   'located': None,
#   'to': None,
#   'area': '88',
#   'latitude': '47.501794',
#   'longitude': '8.236313',
#   'elevation': '406',
#   'depth': '136'},
#  {'name': 'Thunersee',
#   'located': None,
#   'to': None,
#   'area': '48.3',
#   'latitude': '46.69',
#   'longitude': '7.716',
#   'elevation': '558',
#   'depth': '217'},
#  {'name': 'Brienzersee',
#   'located': None,
#   'to': None,
#   'area': '29.8',
#   'latitude': '46.73',
#   'longitude': '7.97',
#   'elevation': '564',
#   'depth': '260'},
#  {'name': 'Vierwaldstättersee',
#   'located': None,
#   'to': None,
#   'area': '113.7',
#   'latitude': '47.0',
#   'longitude': '8.4',
#   'elevation': '434',
#   'depth': '214'},
#  {'name': 'Lago Maggiore',
#   'located': None,
#   'to': None,
#   'area': '216',
#   'latitude': '45.95',
#   'longitude': '8.6',
#   'elevation': '193',
#   'depth': '372'},
#  {'name': 'Lago di Como',
#   'located': None,
#   'to': None,
#   'area': '146',
#   'latitude': '46',
#   'longitude': '9.3',
#   'elevation': '197',
#   'depth': '425'},
#  {'name': 'Lago di Garda',
#   'located': None,
#   'to': None,
#   'area': '370',
#   'latitude': '45.6',
#   'longitude': '10.65',
#   'elevation': '65',
#   'depth': '346'},
#  {'name': 'Lago Trasimeno',
#   'located': None,
#   'area': '128',
#   'latitude': '43.1',
#   'longitude': '12.1',
#   'elevation': '259',
#   'depth': '7'},
#  {'name': 'Lago di Bolsena',
#   'located': None,
#   'to': None,
#   'area': '114',
#   'latitude': '42.6',
#   'longitude': '11.9',
#   'elevation': '335',
#   'depth': '151'},
#  {'name': 'Lago di Bracciano',
#   'located': None,
#   'to': None,
#   'area': '57',
#   'latitude': '42.1',
#   'longitude': '12.2',
#   'elevation': '164',
#   'depth': '165'},
#  {'name': 'Lago Albano',
#   'located': None,
#   'area': '6',
#   'latitude': '41.75',
#   'longitude': '12.66',
#   'elevation': '291',
#   'depth': '170'},
#  {'name': 'Lago Omodeo',
#   'located': None,
#   'to': None,
#   'area': '29',
#   'latitude': '40.14',
#   'longitude': '8.91',
#   'elevation': '118',
#   'depth': '60'},
#  {'name': 'Laguna de Gallocanta',
#   'located': None,
#   'area': '14.4',
#   'latitude': '40.96',
#   'longitude': '-1.5',
#   'elevation': '995',
#   'depth': '1.5'},
#  {'name': 'Neusiedlersee',
#   'located': None,
#   'area': '320',
#   'latitude': '47.8',
#   'longitude': '16.7',
#   'elevation': '115.5',
#   'depth': '1.8'},
#  {'name': 'Balaton',
#   'located': None,
#   'area': '594',
#   'latitude': '46.8',
#   'longitude': '17.6',
#   'elevation': '104',
#   'depth': '12.5'},
#  {'name': 'Lake Skutari',
#   'to': None,
#   'area': '368',
#   'latitude': '42.2',
#   'longitude': '19.3',
#   'elevation': '7',
#   'depth': '44'},
#  {'name': 'Lake Prespa',
#   'located': None,
#   'area': '273',
#   'latitude': '40.9',
#   'longitude': '21.0',
#   'elevation': '849',
#   'depth': '54'},
#  {'name': 'Lake Ohrid',
#   'to': None,
#   'area': '367',
#   'latitude': '41.0',
#   'longitude': '20.7',
#   'elevation': '695',
#   'depth': '289'},
#  {'name': 'Kiev Reservoir',
#   'located': None,
#   'to': None,
#   'area': '922',
#   'latitude': '50.6',
#   'longitude': '30.5',
#   'depth': '8'},
#  {'name': 'Kakhovka Reservoir',
#   'located': None,
#   'to': None,
#   'area': '2155',
#   'latitude': '47.45',
#   'longitude': '34.20',
#   'elevation': '44',
#   'depth': '26'},
#  {'name': 'Kremenchuk Reservoir',
#   'located': None,
#   'to': None,
#   'area': '2252',
#   'latitude': '49.2',
#   'longitude': '32.65',
#   'elevation': '44',
#   'depth': '28'},
#  {'name': 'Rybinsk Reservoir',
#   'located': None,
#   'to': None,
#   'area': '4580',
#   'latitude': '58.7',
#   'longitude': '38.42',
#   'elevation': '102',
#   'depth': '28'},
#  {'name': 'Kuybyshev Reservoir',
#   'located': None,
#   'to': None,
#   'area': '6450',
#   'latitude': '53.5',
#   'longitude': '49.45',
#   'elevation': '53',
#   'depth': '41'},
#  {'name': 'Ozero Ladoga',
#   'located': None,
#   'to': None,
#   'area': '18400',
#   'latitude': '60.82',
#   'longitude': '31.53',
#   'elevation': '4',
#   'depth': '225'},
#  {'name': 'Ozero Onega',
#   'located': None,
#   'to': None,
#   'area': '9616',
#   'latitude': '61.67',
#   'longitude': '35.485',
#   'elevation': '33',
#   'depth': '127'},
#  {'name': 'Ozero Pskovskoje',
#   'located': None,
#   'to': None,
#   'area': '3555',
#   'latitude': '58.68',
#   'longitude': '27.49',
#   'elevation': '30',
#   'depth': '14.6'},
#  {'name': 'Ozero Taimyr',
#   'located': None,
#   'to': None,
#   'area': '4560',
#   'latitude': '74.5',
#   'longitude': '101.6',
#   'elevation': '5',
#   'depth': '26'},
#  {'name': 'Ozero Baikal',
#   'located': None,
#   'to': None,
#   'area': '31492',
#   'latitude': '53',
#   'longitude': '108',
#   'elevation': '455',
#   'depth': '1637'},
#  {'name': 'Ozero Chanka',
#   'located': None,
#   'to': None,
#   'area': '4400',
#   'latitude': '45',
#   'longitude': '132.4',
#   'elevation': '70'},
#  {'name': 'Koltsevoye Lake',
#   'located': None,
#   'area': '10',
#   'latitude': '49.36',
#   'longitude': '154.71',
#   'elevation': '384'},
#  {'name': 'Dead Sea',
#   'located': None,
#   'area': '41650',
#   'latitude': '31.3',
#   'longitude': '35.5',
#   'elevation': '-422',
#   'depth': '378'},
#  {'name': 'Lake Genezareth',
#   'located': None,
#   'to': None,
#   'area': '165',
#   'latitude': '32.81',
#   'longitude': '35.60',
#   'elevation': '-212',
#   'depth': '46'},
#  {'name': 'Lake Van',
#   'located': None,
#   'area': '3740',
#   'latitude': '38.6',
#   'longitude': '42.9',
#   'elevation': '1719',
#   'depth': '457'},
#  {'name': 'Nemrut Gölü',
#   'located': None,
#   'area': '6',
#   'latitude': '38.65',
#   'longitude': '42.23',
#   'elevation': '2200',
#   'depth': '155'},
#  {'name': 'Lake Keban',
#   'located': None,
#   'to': None,
#   'area': '675',
#   'latitude': '38.8',
#   'longitude': '38.75',
#   'elevation': '820'},
#  {'name': 'Lake Sevan',
#   'to': None,
#   'area': '1242',
#   'latitude': '40.3',
#   'longitude': '45.35',
#   'elevation': '1904',
#   'depth': '79'},
#  {'name': 'Lake Urmia',
#   'located': None,
#   'area': '5470',
#   'latitude': '37.7',
#   'longitude': '45.3',
#   'elevation': '1280',
#   'depth': '7'},
#  {'name': 'Daryacheh ye Namak',
#   'located': None,
#   'area': '1800',
#   'latitude': '34.5',
#   'longitude': '51.88',
#   'elevation': '790',
#   'depth': '1'},
#  {'name': 'Lake Hamun',
#   'located': None,
#   'area': '1600',
#   'latitude': '30.8',
#   'longitude': '61.2',
#   'elevation': '500'},
#  {'name': 'Caspian Sea',
#   'located': None,
#   'area': '386400',
#   'latitude': '41',
#   'longitude': '51',
#   'elevation': '-28',
#   'depth': '995'},
#  {'name': 'Garabogazköl',
#   'located': None,
#   'to': None,
#   'area': '18000',
#   'latitude': '41.3',
#   'longitude': '53.6',
#   'elevation': '-28',
#   'depth': '7'},
#  {'name': 'North Aral Sea',
#   'located': None,
#   'area': '3300',
#   'latitude': '46.5',
#   'longitude': '60.7',
#   'elevation': '40',
#   'depth': '18'},
#  {'name': 'South Aral Sea',
#   'located': None,
#   'area': '3500',
#   'latitude': '45.2',
#   'longitude': '58.8',
#   'elevation': '29',
#   'depth': '15'},
#  {'name': 'Ozero Balchash',
#   'located': None,
#   'area': '18428',
#   'latitude': '46.55',
#   'longitude': '74.88',
#   'elevation': '342',
#   'depth': '26'},
#  {'name': 'Issyk-Kul',
#   'area': '6236',
#   'latitude': '42.4',
#   'longitude': '77.2',
#   'elevation': '1609',
#   'depth': '668'},
#  {'name': 'Koli Sarez',
#   'located': None,
#   'to': None,
#   'area': '80',
#   'latitude': '38.2',
#   'longitude': '72.75',
#   'elevation': '3250',
#   'depth': '500'},
#  {'name': 'Lop Nor',
#   'located': None,
#   'area': '5000',
#   'latitude': '40.2',
#   'longitude': '90.6',
#   'elevation': '780',
#   'depth': '0'},
#  {'name': 'Aydingkol',
#   'located': None,
#   'area': '152',
#   'latitude': '42.65',
#   'longitude': '89.27',
#   'elevation': '-155',
#   'depth': '0'},
#  {'name': 'Uws Nuur',
#   'area': '3350',
#   'latitude': '50.3',
#   'longitude': '92.7',
#   'elevation': '753',
#   'depth': '20'},
#  {'name': 'Chöwsgöl Nuur',
#   'to': None,
#   'area': '2760',
#   'latitude': '51.2',
#   'longitude': '100.5',
#   'elevation': '1624',
#   'depth': '262'},
#  {'name': 'Hulun Nur',
#   'located': None,
#   'area': '2315',
#   'latitude': '48.95',
#   'longitude': '117.45',
#   'elevation': '539',
#   'depth': '9'},
#  {'name': 'Qinghai Lake',
#   'located': None,
#   'area': '4583',
#   'latitude': '36.9',
#   'longitude': '100.2',
#   'elevation': '3195'},
#  {'name': 'Nam Co',
#   'located': None,
#   'area': '1855',
#   'latitude': '30.7',
#   'longitude': '90.55',
#   'elevation': '4718',
#   'depth': '125'},
#  {'name': 'Manasarovar',
#   'located': None,
#   'to': None,
#   'area': '412',
#   'latitude': '30.67',
#   'longitude': '81.47',
#   'elevation': '4586',
#   'depth': '77'},
#  {'name': 'Rakshastal',
#   'located': None,
#   'to': None,
#   'area': '258',
#   'latitude': '30.7',
#   'longitude': '81.23',
#   'elevation': '4572'},
#  {'name': 'Hongze Hu',
#   'located': None,
#   'to': None,
#   'area': '1855',
#   'latitude': '33.3',
#   'longitude': '118.7',
#   'elevation': '15'},
#  {'name': 'Tai Hu',
#   'located': None,
#   'area': '2250',
#   'latitude': '31.17',
#   'longitude': '120.15',
#   'elevation': '15'},
#  {'name': 'Poyang Hu',
#   'located': None,
#   'area': '3585',
#   'latitude': '29.1',
#   'longitude': '116.3',
#   'elevation': '16.5',
#   'depth': '25'},
#  {'name': 'Dongting Hu',
#   'located': None,
#   'area': '2820',
#   'latitude': '29.3',
#   'longitude': '112.95'},
#  {'name': 'Heaven Lake',
#   'located': None,
#   'area': '9.82',
#   'latitude': '42.00',
#   'longitude': '128.06',
#   'elevation': '2189',
#   'depth': '384'},
#  {'name': 'Lake Biwa',
#   'located': None,
#   'to': None,
#   'area': '670',
#   'latitude': '35.32',
#   'longitude': '136.17',
#   'elevation': '85',
#   'depth': '104'},
#  {'name': 'Lake Pinatubo',
#   'located': None,
#   'area': '1.8',
#   'latitude': '15.14',
#   'longitude': '120.3',
#   'elevation': '900',
#   'depth': '600'},
#  {'name': 'Lake Taal',
#   'located': None,
#   'to': None,
#   'area': '234.2',
#   'latitude': '13.98',
#   'longitude': '121.02',
#   'elevation': '5',
#   'depth': '172'},
#  {'name': 'Taal Crater Lake',
#   'located': None,
#   'area': '0.3',
#   'latitude': '14.00',
#   'longitude': '121.00',
#   'elevation': '5',
#   'depth': '172'},
#  {'name': 'Laguna de Bay',
#   'located': None,
#   'area': '911',
#   'latitude': '14.4',
#   'longitude': '121.35',
#   'depth': '20'},
#  {'name': 'Lake Lanao',
#   'located': None,
#   'to': None,
#   'area': '354.6',
#   'latitude': '7.9',
#   'longitude': '124.25',
#   'elevation': '905',
#   'depth': '701'},
#  {'name': 'Lake Toba',
#   'located': None,
#   'to': None,
#   'area': '1103',
#   'latitude': '2.6',
#   'longitude': '98.8',
#   'elevation': '905',
#   'depth': '505'},
#  {'name': 'Danau Kumbang',
#   'located': None,
#   'area': '0.04',
#   'latitude': '-2.50',
#   'longitude': '101.86',
#   'elevation': '2560'},
#  {'name': 'Segara Anak',
#   'located': None,
#   'area': '11.3',
#   'latitude': '-8.40',
#   'longitude': '116.45',
#   'elevation': '2008',
#   'depth': '190'},
#  {'name': 'Tonle Sap',
#   'to': None,
#   'area': '16000',
#   'latitude': '12.88',
#   'longitude': '104.07',
#   'elevation': '0.5',
#   'depth': '10'},
#  {'name': 'Songkhla Lake',
#   'to': None,
#   'area': '1040',
#   'latitude': '7.2',
#   'longitude': '100.47',
#   'elevation': '0'},
#  {'name': 'Lake Nasser',
#   'located': None,
#   'to': None,
#   'area': '5250',
#   'latitude': '22.4',
#   'longitude': '31.75',
#   'elevation': '183',
#   'depth': '180'},
#  {'name': 'Chott Melrhir',
#   'area': '6700',
#   'latitude': '34.33',
#   'longitude': '6.33',
#   'elevation': '-40',
#   'depth': '3'},
#  {'name': 'Lake Kossou',
#   'located': None,
#   'to': None,
#   'area': '1898',
#   'latitude': '7.00',
#   'longitude': '-5.50',
#   'elevation': '195',
#   'height': '58'},
#  {'name': 'Lake Volta',
#   'located': None,
#   'to': None,
#   'area': '8502',
#   'latitude': '6.3',
#   'longitude': '0.5',
#   'depth': '130'},
#  ...]

# %%
countries_dt=pd.DataFrame(list_countries)

# %%
countries_dt.head()
# Out:
#               name population population_growth infant_mortality gdp_total  \
# 0          Albania    2821977               0.3            13.19     12800
# 1           Greece   10816286              0.01             4.78    243300
# 2  North Macedonia    2059794              0.21              7.9     10650
# 3           Serbia    7120666             -0.46             6.16     43680
# 4       Montenegro     620029             -0.49              NaN      4518
#
#   gdp_agri gdp_ind gdp_serv inflation unemployment  ... estuary through  \
# 0     19.5      12     68.5       1.7         16.9  ...     NaN     NaN
# 1      3.5      16     80.5      -0.8         27.9  ...     NaN     NaN
# 2     10.2    27.5     62.3       2.8         28.6  ...     NaN     NaN
# 3      7.9    31.8     60.3       2.2         20.1  ...     NaN     NaN
# 4      0.8    11.3     87.9         4         19.1  ...     NaN     NaN
#
#    latitude longitude elevation height  islands mountains gmtOffset located_on
# 0       NaN       NaN       NaN    NaN      NaN       NaN       NaN        NaN
# 1       NaN       NaN       NaN    NaN      NaN       NaN       NaN        NaN
# 2       NaN       NaN       NaN    NaN      NaN       NaN       NaN        NaN
# 3       NaN       NaN       NaN    NaN      NaN       NaN       NaN        NaN
# 4       NaN       NaN       NaN    NaN      NaN       NaN       NaN        NaN
#
# [5 rows x 40 columns]

# %%
countries_dt['infant_mortality']=countries_dt['infant_mortality'].astype('float64')

# %%
countries_dt[['name','infant_mortality']].sort_values(['infant_mortality']).head(10)
# Out:
#                name  infant_mortality
# 38           Monaco              1.81
# 98            Japan              2.13
# 117         Bermuda              2.48
# 36           Norway              2.48
# 106       Singapore              2.53
# 37           Sweden              2.60
# 10   Czech Republic              2.63
# 8             Spain              2.70
# 78        Hong Kong              2.73
# 79            Macao              3.13

# %%
countries_dt['population']=countries_dt['population'].astype('float64')

# %%
countries_dt[['name','population']].sort_values(['population'], ascending=False).head(10)
# Out:
#               name    population
# 55           China  1.360720e+09
# 67           India  1.210855e+09
# 120  United States  3.188571e+08
# 88       Indonesia  2.521245e+08
# 57        Pakistan  2.077770e+08
# 176         Brazil  2.027686e+08
# 202        Nigeria  1.933925e+08
# 65      Bangladesh  1.497724e+08
# 23          Russia  1.436669e+08
# 98           Japan  1.272980e+08

# %%
countries_dt.columns
# Out:
# Index(['name', 'population', 'population_growth', 'infant_mortality',
#        'gdp_total', 'gdp_agri', 'gdp_ind', 'gdp_serv', 'inflation',
#        'unemployment', 'indep_date', 'government', 'encompassed',
#        'ethnicgroup', 'religion', 'language', 'border', 'city', 'localname',
#        'province', 'dependent', 'area', 'abbrev', 'established', 'members',
#        'located', 'depth', 'to', 'length', 'source', 'estuary', 'through',
#        'latitude', 'longitude', 'elevation', 'height', 'islands', 'mountains',
#        'gmtOffset', 'located_on'],
#       dtype='object')

# %%
list_cities=[]
for country in root:
    cities_dict={}
    for city in country.findall('city'):
        for city_prop in city:
            cities_dict[city_prop.tag]=city_prop.text
    if cities_dict:
        list_cities.append(cities_dict)

# %%
list_cities
# Out:
# [{'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
# ...
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  {'name': 'Victoria',
#   'latitude': '-4.62',
#   'longitude': '55.45',
#   'elevation': '10',
#   'population': '24970',
#   'located_at': None,
#   'localname': 'سوسة ',
#   'located_on': None},
#  ...]

# %%
cities_dt=pd.DataFrame(list_cities)

# %%
cities_dt['population']=cities_dt['population'].astype('float64')

# %%
cities_dt[['name','population']].sort_values(['population'], ascending=False).head(10)
# Out:
#           name  population
# 0     Victoria     24970.0
# 2260  Victoria     24970.0
# 2262  Victoria     24970.0
# 2263  Victoria     24970.0
# 2264  Victoria     24970.0
# 2265  Victoria     24970.0
# 2266  Victoria     24970.0
# 2267  Victoria     24970.0
# 2268  Victoria     24970.0
# 2269  Victoria     24970.0

# %%
cities_dt[['name','population']][cities_dt['name']=="Busan"]
# Out:
# Empty DataFrame
# Columns: [name, population]
# Index: []
